# %%
import pandas as pd
data13=pd.read_excel('C:/Users/李征/Documents/a国赛/13.xlsx')
data13
# Out:
#         Unnamed: 0       开票日期       金额       税额     价税合计  发票状态
# 0                1 2017-08-04  9401.71  1598.29  11000.0  有效发票
# 1                1 2017-08-09  8170.94  1389.06   9560.0  有效发票
# 2                1 2017-08-09  8170.94  1389.06   9560.0  有效发票
# 3                1 2017-08-09  4085.47   694.53   4780.0  有效发票
# 4                1 2017-08-09  4085.47   694.53   4780.0  有效发票
# ...            ...        ...      ...      ...      ...   ...
# 162479         123 2019-12-17  4827.67   144.83   4972.5  有效发票
# 162480         123 2019-12-17  7412.62   222.38   7635.0  有效发票
# 162481         123 2019-12-17  1917.47    57.53   1975.0  有效发票
# 162482         123 2019-12-25  7252.42   217.58   7470.0  有效发票
# 162483         123 2019-12-25  6660.19   199.81   6860.0  有效发票
#
# [162484 rows x 6 columns]

# %%
data13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162484 entries, 0 to 162483
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  162484 non-null  int64
#  1   发票号码        162484 non-null  int64
#  2   开票日期        162484 non-null  datetime64[ns]
#  3   购方单位代号      162484 non-null  object
#  4   金额          162484 non-null  float64
#  5   税额          162484 non-null  float64
#  6   价税合计        162484 non-null  float64
#  7   发票状态        162484 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 9.9+ MB

# %%
data13.describe()
# Out:
#           Unnamed: 0          发票号码            金额             税额          价税合计
# count  162484.000000  1.624840e+05  1.624840e+05  162484.000000  1.624840e+05
# mean       26.222576  9.392893e+06  8.687789e+04   11045.383030  9.792327e+04
# std        27.466022  1.075577e+07  2.099776e+05   31589.324542  2.401681e+05
# min         1.000000  1.376000e+03 -9.997715e+05 -169961.160000 -1.169733e+06
# 25%         3.000000  2.910115e+06  2.724215e+03     253.260000  3.018400e+03
# 50%        13.000000  6.007244e+06  1.752148e+04    1699.860000  1.979208e+04
# 75%        46.000000  1.195165e+07  9.213362e+04    8256.880000  1.000000e+05
# max       123.000000  9.828650e+07  3.978957e+06  636633.100000  4.615590e+06

# %%
#删除作废发票
new13=data13.drop(data13.loc[(data13['发票状态']=='作废发票')].index)
new13=new13.drop(new13.loc[(new13['金额']==0)].index)
new13
# Out:
#         Unnamed: 0      发票号码       开票日期  购方单位代号       金额       税额     价税合计  \
# 0                1  11459356 2017-08-04  B03711  9401.71  1598.29  11000.0
# 1                1   5076239 2017-08-09  B00844  8170.94  1389.06   9560.0
# 2                1   5076240 2017-08-09  B00844  8170.94  1389.06   9560.0
# 3                1   5076241 2017-08-09  B00844  4085.47   694.53   4780.0
# 4                1   5076242 2017-08-09  B00844  4085.47   694.53   4780.0
# ...            ...       ...        ...     ...      ...      ...      ...
# 162479         123   8887701 2019-12-17  B10944  4827.67   144.83   4972.5
# 162480         123   8887702 2019-12-17  B10944  7412.62   222.38   7635.0
# 162481         123  34173085 2019-12-17  B13093  1917.47    57.53   1975.0
# 162482         123   8887703 2019-12-25  B13093  7252.42   217.58   7470.0
# 162483         123   8887704 2019-12-25  B13093  6660.19   199.81   6860.0
#
#         发票状态
# 0       有效发票
# 1       有效发票
# 2       有效发票
# ...

# %%
new13.loc[(new13['发票状态']=='作废发票')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 发票号码, 开票日期, 购方单位代号, 金额, 税额, 价税合计, 发票状态]
# Index: []

# %%
import matplotlib.pyplot as plt
pre=new13.values[:,5]/new13.values[:,4]
plt.plot(pre)

# %%
# for i in data12.values[:,5]:
#     print(type(i))
#     if i=="作废发票":
#           print(i)

# %%
sums=[]
for i in range(1,124):
    name=data13.loc[(data13['Unnamed: 0']==i)]["税额"]
    #print(name)
    sums.append(sum(name))
sums,len(sums)
# Out:
# ([645818302.9499989,
#   39326331.020000726,
#   93952826.35000007,
#   334450797.7599991,
#   31986902.040000048,
#   32666524.18999989,
#   85386455.53000008,
#   24858707.409999475,
#   51343881.11000007,
#   11623544.870000055,
#   14487292.670000128,
#   20887703.319999985,
#   35643322.40000007,
#   35843696.690000094,
#   8384021.7200002195,
#   4492793.030000002,
#   16040253.840000011,
#   10811028.929999996,
#   31652312.420000013,
#   32393189.190000065,
#   11622586.770000355,
#   12582455.080000145,
#   29276573.36000003,
#   14922080.970000053,
#   6455932.880000004,
#   6381596.630000003,
#   4800028.199999983,
#   5207887.329999979,
#   1825511.2200000011,
#   7127864.930000001,
#   7280788.850000009,
#   1419485.0900000124,
#   5628495.430000006,
#   5605161.919999999,
#   3746520.309999998,
#   5352369.159999997,
#   7411968.109999989,
#   2056675.3600000138,
#   4166160.880000002,
#   823660.2199999999,
#   851285.7499999998,
#   0.0,
#   1548067.7999999954,
# ...

# %%
new13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151278 entries, 0 to 162483
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  151278 non-null  int64
#  1   发票号码        151278 non-null  int64
#  2   开票日期        151278 non-null  datetime64[ns]
#  3   购方单位代号      151278 non-null  object
#  4   金额          151278 non-null  float64
#  5   税额          151278 non-null  float64
#  6   价税合计        151278 non-null  float64
#  7   发票状态        151278 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 10.4+ MB
