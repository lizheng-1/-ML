# %%
import pandas as pd
data13=pd.read_excel('C:/Users/李征/Documents/a国赛/13.xlsx')
data12=pd.read_excel('C:/Users/李征/Documents/a国赛/12.xlsx')

# %%
#删除作废发票
#删除作废发票
new12=data12.drop(data12.loc[(data12['发票状态']=='作废发票')].index)
new13=data13.drop(data13.loc[(data13['发票状态']=='作废发票')].index)
new13=new13.drop(new13.loc[(new13['金额']==0)].index)
sums=[]
for i in range(1,124):
    n1=data13.loc[(data13['Unnamed: 0']==i)]["税额"]
    n2=data12.loc[(data12['Unnamed: 0']==i)]["税额"]
    #print(name)
    sums.append(sum(n1)+sum(n2))
sums,len(sums)
# Out:
# ([1574484761.5299978,
#   46518636.35000008,
#   96282840.39000008,
#   386691649.0599991,
#   62096354.280000314,
#   53037675.51000005,
#   89337505.25,
#   33403792.889999025,
#   53155083.94000007,
#   11944728.190000057,
#   26509465.55000023,
#   27980255.86999998,
#   48003970.18999908,
#   51169051.6300001,
#   8949507.16000022,
#   4508375.160000002,
#   29680056.649999816,
#   21576593.75999945,
#   61890166.68000009,
#   61816913.17000015,
#   20922127.36000033,
#   22527157.520000175,
#   56738677.56000018,
#   26068947.459999967,
#   7502262.470000003,
#   12170954.720000006,
#   9732022.649999976,
#   5366587.589999978,
#   1851584.7600000012,
#   10339077.679999998,
#   7932091.450000009,
#   1611843.010000014,
#   6983582.390000006,
#   9815847.270000001,
#   7699332.010000002,
#   8365656.509999996,
#   14286752.349999987,
#   3199758.4000000143,
#   4189214.9800000023,
#   1053503.340000001,
#   1175128.6600000001,
#   1343.3700000000001,
#   2214650.8999999953,
# ...
